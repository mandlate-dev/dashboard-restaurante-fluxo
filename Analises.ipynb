# %%
import pandas as pd

# %%
df1 = pd.read_excel('Dataset Restaurante Mocambique.xlsx', sheet_name='Pedidos')
df2 = pd.read_excel('Dataset Restaurante Mocambique.xlsx', sheet_name='Itens_Pedido')
df3 = pd.read_excel('Dataset Restaurante Mocambique.xlsx', sheet_name='Cardapio')
df4 = pd.read_excel('Dataset Restaurante Mocambique.xlsx', sheet_name='Funcionarios')
df5 = pd.read_excel('Dataset Restaurante Mocambique.xlsx', sheet_name='Dicionario_Dados')

# %%
itens_cardapio = pd.merge(df2, df3, how='inner')

# %%
itens_cardapio
# Out:
#         item_id pedido_id prato_id  quantidade  preco_unitario_mzn  \
# 0      IT000001  PED00001     P004           1                 400
# 1      IT000002  PED00001     P005           1                 850
# 2      IT000003  PED00002     P010           1                 600
# 3      IT000004  PED00002     P014           2                 180
# 4      IT000005  PED00002     P002           1                 500
# ...         ...       ...      ...         ...                 ...
# 10169  IT010170  PED02735     P005           1                 850
# 10170  IT010171  PED02735     P010           1                 600
# 10171  IT010172  PED02735     P015           1                 280
# 10172  IT010173  PED02736     P003           1                 650
# 10173  IT010174  PED02737     P005           1                 850
#
#                        nome_prato        categoria  preco_venda_mzn  \
# 0        Xima com Frango Grelhado  Prato Principal              400
# ...

# %%
itens_cardapio['nome_prato'].nunique()
# Out:
# 30
